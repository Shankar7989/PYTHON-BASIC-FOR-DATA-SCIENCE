# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=sns.load_dataset('mpg')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82     usa  ford mustang gl
# 394          82  europe        vw pickup
# 395          82     usa    dodge rampage
# 396          82     usa      ford ranger
# 397          82     usa       chevy s-10

# %%
df.drop(['origin','name'],axis=1,inplace=True)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  model_year
# 0  18.0          8         307.0       130.0    3504          12.0          70
# 1  15.0          8         350.0       165.0    3693          11.5          70
# 2  18.0          8         318.0       150.0    3436          11.0          70
# 3  16.0          8         304.0       150.0    3433          12.0          70
# 4  17.0          8         302.0       140.0    3449          10.5          70

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# dtype: int64

# %%
x=df.drop(['mpg'],axis=1)
y=df['mpg']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.85) # Corrected the order of returned variables

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x=df.drop(['mpg'],axis=1)
y=df['mpg']

# %%
y_pred=model.predict(x_test)

# %%
def evaluation_metrics(actual,pred):
  MAE=mean_squared_error(actual,pred)
  MSE=mean_squared_error(actual,pred)
  RMSE=np.sqrt(MSE)
  score=r2_score(actual,pred)
  return print('r2_score:',score,'/n',MAE,'/n','mse:',MSE,'/n','rmse:',RMSE)

# %%
evaluation_metrics(y_test,y_pred)
# Out:
# r2_score: 0.8480392924116892 /n 10.318729236421198 /n mse: 10.318729236421198 /n rmse: 3.2122778890409216

# %%
from sklearn.model_selection import cross_val_score

# %%
accuracies = cross_val_score(estimator=model, X=x_train, y=y_train, cv=10)

# %%
#cv 10 means 10 train and 10 test data sets

# %%
accuracies
# Out:
# array([0.75580678, 0.68893754, 0.76351066, 0.80967468, 0.77546947,
#        0.85058275, 0.85230173, 0.82176164, 0.68399713, 0.85729369])

# %%
accuracies.mean()
# Out:
# 0.7859336060917443

# %%
accuracies = cross_val_score(estimator=model, X=x_train, y=y_train, cv=10,scoring='neg_mean_squared_error')

# %%
accuracies.mean()
# Out:
# -12.346591235165922

# %%
-accuracies.mean()
# Out:
# 12.346591235165922
